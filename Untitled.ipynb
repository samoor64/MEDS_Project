# %%
import pandas as pd
import matplotlib as plt
import numpy as np

ca_df = pd.read_csv('CAvideos.csv', encoding='latin-1' )

ca_df.head()
# Out:
#       video_id trending_date  \
# 0  FlsCjmMhFmw      17.13.12
# 1  FlsCjmMhFmw      17.12.12
# 2  FlsCjmMhFmw      17.11.12
# 3  FlsCjmMhFmw      17.10.12
# 4  FlsCjmMhFmw      17.09.12
#
#                                                title      channel_title  \
# 0  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 1  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 2  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 3  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
# 4  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  YouTube Spotlight
#
#    category_id              publish_time  \
# 0           24  2017-12-06T17:58:51.000Z
# 1           24  2017-12-06T17:58:51.000Z
# 2           24  2017-12-06T17:58:51.000Z
# 3           24  2017-12-06T17:58:51.000Z
# 4           24  2017-12-06T17:58:51.000Z
#
#                                                 tags      views    likes  \
# ...

# %%
vid_group = ca_df.groupby(['title']).sum()

vid_group
# Out:
#                                                     category_id     views  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...           20    835930
# #1 Fortnite World Rank - 2,323 Solo Wins!                    20    212838
# #1 Fortnite World Rank - 2,330 Solo Wins!                    20    200764
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R...           48    311914
# #1 WORLD RANKED 1463 SOLO WINS! - FORTNITE BATT...           20    541482
# #1 WORLD RECORD 3,288 SOLO WINS                              20    305919
# #1 World Ranked - 1,700 Solo Wins -  New Minigu...           20    617348
# #1 World Record 3,225 Solo Wins | Fortnite Live...           20    152389
# #1 World Record 3,359 Solo Wins | Fortnite Live...           20    229842
# #10 Most Emotional Moments in Cricket History |...           34  10210272
# #267 DID JESUS EXIST?? Jordan Peterson and Lind...           69    699899
# #271 DOES JERUSALEM BELONG TO ISRAEL?? Ted Cruz...           23    239763
# ...
